# %%
import tensorflow as tf
import numpy as np
from tqdm import trange
from collections import OrderedDict
import time

# %%
tf.random.set_seed(60)

# %%
X = tf.linspace(0.0, 10.0, 1000)
X = tf.reshape(X, (-1, 1)) 
alpha = np.random.rand(X.shape[-1])
beta = np.random.rand(X.shape[-1])

# %%
class LayerNormalization(tf.keras.layers.Layer):
    def __init__(self, small = 10**(-5) ,**kwargs):
        super().__init__(**kwargs)
        self.small = small

    def build(self, shape):
        self.alpha = self.add_weight(initializer="ones", shape=shape[-1:], name="alpha")
        self.beta = self.add_weight(initializer="zeros", shape=shape[-1:], name="beta")

    def call(self, x):
        mean, variance = tf.nn.moments(x, axes=-1,keepdims=True)
        return self.alpha * (x - mean)/tf.sqrt(self.alpha + self.small) + self.beta

    def get_config(self):
        base = super().get_config()
        return {**base, 'small': self.small}

# %%
customLayerNorm = LayerNormalization()
LayerNorm = tf.keras.layers.LayerNormalization()

# %%
customLayerNorm.build(X.shape)
LayerNorm.build(X.shape)
customLayerNorm.set_weights([alpha, beta])
LayerNorm.set_weights([alpha, beta])

# %%
mae = tf.keras.losses.MeanAbsoluteError()
loss = mae(customLayerNorm(X), LayerNorm(X))
tf.reduce_mean(loss)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=8.172988827936933e-07>

# %%
(X_train_full, y_train_full), (X_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
X_train_full = X_train_full.astype(np.float32) / 255.
X_train, X_val = X_train_full[:50000], X_train_full[50000:]
y_train, y_val = y_train_full[:50000], y_train_full[50000:]
X_test = X_test.astype(np.float32) / 255.

# %%
lower_layers = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(200, activation="relu"),
    tf.keras.layers.Dense(200, activation="relu"),
])
upper_layers = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation="softmax"),
])
model = tf.keras.Sequential([
    lower_layers, upper_layers
])

# %%
lower_optimizer = tf.keras.optimizers.SGD(learning_rate=0.01,  momentum=0.99, nesterov=True)
upper_optimizer = tf.keras.optimizers.Nadam(learning_rate=1e-4)

# %%
n_epochs = 1
batch_size = 50
n_steps = len(X_train) // batch_size
loss = tf.keras.losses.sparse_categorical_crossentropy
mean_loss = tf.keras.metrics.Mean()
metrics = [tf.keras.metrics.SparseCategoricalAccuracy()]

# %%
def random_batch(X, y, batch_size=32):
    idx = np.random.randint(len(X), size=batch_size)
    return X[idx], y[idx]

# %%
with trange(1, n_epochs + 1, desc="All epochs") as epochs:
    for epoch in epochs:
        with trange(1, n_steps + 1, desc=f"Epoch {epoch}/{n_epochs}") as steps:
            for step in steps:
                time.sleep(0.001)
                X_batch, y_batch = random_batch(X_train, y_train)
                with tf.GradientTape(persistent=True) as tape:
                    y_pred = model(X_batch)
                    main_loss = tf.reduce_mean(loss(y_batch, y_pred))
                    total_loss = tf.add_n([main_loss] + model.losses)
                for layers, optimizer in ((lower_layers, lower_optimizer), (upper_layers, upper_optimizer)):
                    gradients = tape.gradient(total_loss, layers.trainable_variables)
                    optimizer.apply_gradients(zip(gradients, layers.trainable_variables))
                del tape
                for variable in model.variables:
                    if variable.constraint is not None:
                        variable.assign(variable.constraint(variable))                    
                status = OrderedDict()
                mean_loss(total_loss)
                status["loss"] = mean_loss.result().numpy()
                for metric in metrics:
                    metric(y_batch, y_pred)
                    status[metric.name] = metric.result().numpy()
                steps.set_postfix(status, refresh=False)
            y_pred = model(X_val)
            status["val_loss"] = np.mean(loss(y_val, y_pred))
            status["val_accuracy"] = np.mean(tf.keras.metrics.sparse_categorical_accuracy(
                tf.constant(y_val, dtype=np.float32), y_pred))
            steps.set_postfix(status)
        for metric in [mean_loss] + metrics:
            metric.reset_state()
# Out:
# All epochs:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 1/1000 [00:00<02:46,  6.00it/s, loss=2.42, sparse_categorical_accuracy=0.0625]
# Epoch 1/1:   0%|          | 3/1000 [00:00<01:23, 11.93it/s, loss=2.37, sparse_categorical_accuracy=0.104]
# Epoch 1/1:   1%|          | 6/1000 [00:00<00:58, 17.01it/s, loss=2.27, sparse_categorical_accuracy=0.177]
# Epoch 1/1:   1%|          | 9/1000 [00:00<00:49, 20.18it/s, loss=2.16, sparse_categorical_accuracy=0.278]
# Epoch 1/1:   1%|          | 12/1000 [00:00<00:50, 19.48it/s, loss=2.08, sparse_categorical_accuracy=0.341]
# Epoch 1/1:   2%|▏         | 15/1000 [00:00<00:46, 21.17it/s, loss=1.98, sparse_categorical_accuracy=0.39]
# Epoch 1/1:   2%|▏         | 18/1000 [00:00<00:45, 21.38it/s, loss=1.86, sparse_categorical_accuracy=0.434]
# Epoch 1/1:   2%|▏         | 21/1000 [00:01<00:44, 21.88it/s, loss=1.79, sparse_categorical_accuracy=0.449]
# Epoch 1/1:   2%|▏         | 24/1000 [00:01<00:44, 22.00it/s, loss=1.71, sparse_categorical_accuracy=0.462]
# Epoch 1/1:   3%|▎         | 27/1000 [00:01<00:45, 21.46it/s, loss=1.63, sparse_categorical_accuracy=0.481]
# Epoch 1/1:   3%|▎         | 30/1000 [00:01<00:47, 20.35it/s, loss=1.56, sparse_categorical_accuracy=0.488]
# Epoch 1/1:   3%|▎         | 33/1000 [00:01<00:45, 21.05it/s, loss=1.51, sparse_categorical_accuracy=0.498]
# Epoch 1/1:   4%|▎         | 36/1000 [00:01<00:45, 21.34it/s, loss=1.45, sparse_categorical_accuracy=0.515]
# Epoch 1/1:   4%|▍         | 39/1000 [00:01<00:44, 21.68it/s, loss=1.41, sparse_categorical_accuracy=0.522]
# Epoch 1/1:   4%|▍         | 42/1000 [00:02<00:42, 22.69it/s, loss=1.37, sparse_categorical_accuracy=0.531]
# Epoch 1/1:   4%|▍         | 45/1000 [00:02<00:44, 21.23it/s, loss=1.34, sparse_categorical_accuracy=0.541]
# Epoch 1/1:   5%|▍         | 48/1000 [00:02<00:44, 21.54it/s, loss=1.29, sparse_categorical_accuracy=0.555]
# Epoch 1/1:   5%|▌         | 51/1000 [00:02<00:45, 21.05it/s, loss=1.27, sparse_categorical_accuracy=0.562]
# Epoch 1/1:   5%|▌         | 54/1000 [00:02<00:42, 22.16it/s, loss=1.24, sparse_categorical_accuracy=0.572]
# Epoch 1/1:   6%|▌         | 57/1000 [00:02<00:42, 22.35it/s, loss=1.24, sparse_categorical_accuracy=0.573]
# Epoch 1/1:   6%|▌         | 60/1000 [00:02<00:42, 22.36it/s, loss=1.21, sparse_categorical_accuracy=0.581]
# Epoch 1/1:   6%|▋         | 63/1000 [00:03<00:42, 22.29it/s, loss=1.19, sparse_categorical_accuracy=0.586]
# Epoch 1/1:   7%|▋         | 66/1000 [00:03<00:42, 21.76it/s, loss=1.18, sparse_categorical_accuracy=0.593]
# Epoch 1/1:   7%|▋         | 69/1000 [00:03<00:45, 20.48it/s, loss=1.17, sparse_categorical_accuracy=0.597]
# Epoch 1/1:   7%|▋         | 72/1000 [00:03<00:42, 21.74it/s, loss=1.16, sparse_categorical_accuracy=0.599]
# Epoch 1/1:   8%|▊         | 75/1000 [00:03<00:42, 21.96it/s, loss=1.15, sparse_categorical_accuracy=0.605]
# Epoch 1/1:   8%|▊         | 78/1000 [00:03<00:42, 21.46it/s, loss=1.15, sparse_categorical_accuracy=0.607]
# Epoch 1/1:   8%|▊         | 81/1000 [00:03<00:40, 22.46it/s, loss=1.15, sparse_categorical_accuracy=0.61]
# Epoch 1/1:   8%|▊         | 84/1000 [00:03<00:43, 21.24it/s, loss=1.13, sparse_categorical_accuracy=0.617]
# Epoch 1/1:   9%|▊         | 87/1000 [00:04<00:44, 20.72it/s, loss=1.12, sparse_categorical_accuracy=0.62]
# Epoch 1/1:   9%|▉         | 90/1000 [00:04<00:44, 20.49it/s, loss=1.12, sparse_categorical_accuracy=0.624]
# Epoch 1/1:   9%|▉         | 93/1000 [00:04<00:46, 19.69it/s, loss=1.11, sparse_categorical_accuracy=0.627]
# Epoch 1/1:  10%|▉         | 95/1000 [00:04<00:46, 19.54it/s, loss=1.11, sparse_categorical_accuracy=0.63]
# Epoch 1/1:  10%|▉         | 97/1000 [00:04<00:45, 19.65it/s, loss=1.1, sparse_categorical_accuracy=0.63]
# Epoch 1/1:  10%|█         | 100/1000 [00:04<00:41, 21.47it/s, loss=1.1, sparse_categorical_accuracy=0.633]
# Epoch 1/1:  10%|█         | 103/1000 [00:04<00:44, 20.33it/s, loss=1.1, sparse_categorical_accuracy=0.637]
# Epoch 1/1:  11%|█         | 106/1000 [00:05<00:44, 20.25it/s, loss=1.08, sparse_categorical_accuracy=0.642]
# Epoch 1/1:  11%|█         | 109/1000 [00:05<00:42, 20.81it/s, loss=1.08, sparse_categorical_accuracy=0.644]
# Epoch 1/1:  11%|█         | 112/1000 [00:05<00:41, 21.24it/s, loss=1.07, sparse_categorical_accuracy=0.648]
# Epoch 1/1:  12%|█▏        | 115/1000 [00:05<00:43, 20.40it/s, loss=1.06, sparse_categorical_accuracy=0.651]
# Epoch 1/1:  12%|█▏        | 118/1000 [00:05<00:42, 20.79it/s, loss=1.05, sparse_categorical_accuracy=0.652]
# Epoch 1/1:  12%|█▏        | 121/1000 [00:05<00:41, 21.25it/s, loss=1.05, sparse_categorical_accuracy=0.654]
# Epoch 1/1:  12%|█▏        | 124/1000 [00:05<00:39, 22.28it/s, loss=1.04, sparse_categorical_accuracy=0.657]
# Epoch 1/1:  13%|█▎        | 127/1000 [00:06<00:40, 21.73it/s, loss=1.03, sparse_categorical_accuracy=0.659]
# Epoch 1/1:  13%|█▎        | 130/1000 [00:06<00:41, 21.15it/s, loss=1.02, sparse_categorical_accuracy=0.661]
# Epoch 1/1:  13%|█▎        | 133/1000 [00:06<00:40, 21.62it/s, loss=1.02, sparse_categorical_accuracy=0.661]
# Epoch 1/1:  14%|█▎        | 136/1000 [00:06<00:40, 21.09it/s, loss=1.01, sparse_categorical_accuracy=0.662]
# Epoch 1/1:  14%|█▍        | 139/1000 [00:06<00:40, 21.51it/s, loss=1, sparse_categorical_accuracy=0.665]
# Epoch 1/1:  14%|█▍        | 142/1000 [00:06<00:39, 21.78it/s, loss=0.993, sparse_categorical_accuracy=0.667]
# Epoch 1/1:  14%|█▍        | 145/1000 [00:06<00:40, 21.29it/s, loss=0.986, sparse_categorical_accuracy=0.67]
# Epoch 1/1:  15%|█▍        | 148/1000 [00:07<00:39, 21.46it/s, loss=0.977, sparse_categorical_accuracy=0.673]
# Epoch 1/1:  15%|█▌        | 151/1000 [00:07<00:41, 20.68it/s, loss=0.972, sparse_categorical_accuracy=0.675]
# Epoch 1/1:  15%|█▌        | 154/1000 [00:07<00:39, 21.65it/s, loss=0.965, sparse_categorical_accuracy=0.676]
# Epoch 1/1:  16%|█▌        | 157/1000 [00:07<00:39, 21.27it/s, loss=0.957, sparse_categorical_accuracy=0.678]
# Epoch 1/1:  16%|█▌        | 160/1000 [00:07<00:41, 20.10it/s, loss=0.95, sparse_categorical_accuracy=0.68]
# Epoch 1/1:  16%|█▋        | 163/1000 [00:07<00:40, 20.60it/s, loss=0.948, sparse_categorical_accuracy=0.681]
# Epoch 1/1:  17%|█▋        | 166/1000 [00:07<00:40, 20.51it/s, loss=0.945, sparse_categorical_accuracy=0.682]
# Epoch 1/1:  17%|█▋        | 169/1000 [00:08<00:39, 21.13it/s, loss=0.938, sparse_categorical_accuracy=0.683]
# Epoch 1/1:  17%|█▋        | 172/1000 [00:08<00:38, 21.39it/s, loss=0.932, sparse_categorical_accuracy=0.686]
# Epoch 1/1:  18%|█▊        | 175/1000 [00:08<00:37, 21.86it/s, loss=0.93, sparse_categorical_accuracy=0.687]
# Epoch 1/1:  18%|█▊        | 178/1000 [00:08<00:39, 20.60it/s, loss=0.924, sparse_categorical_accuracy=0.689]
# Epoch 1/1:  18%|█▊        | 181/1000 [00:08<00:38, 21.06it/s, loss=0.919, sparse_categorical_accuracy=0.69]
# Epoch 1/1:  18%|█▊        | 184/1000 [00:08<00:37, 21.55it/s, loss=0.916, sparse_categorical_accuracy=0.692]
# Epoch 1/1:  19%|█▊        | 187/1000 [00:08<00:37, 21.83it/s, loss=0.913, sparse_categorical_accuracy=0.693]
# Epoch 1/1:  19%|█▉        | 190/1000 [00:09<00:35, 22.82it/s, loss=0.907, sparse_categorical_accuracy=0.695]
# Epoch 1/1:  19%|█▉        | 193/1000 [00:09<00:35, 22.79it/s, loss=0.9, sparse_categorical_accuracy=0.698]
# Epoch 1/1:  20%|█▉        | 196/1000 [00:09<00:36, 21.89it/s, loss=0.896, sparse_categorical_accuracy=0.698]
# Epoch 1/1:  20%|█▉        | 199/1000 [00:09<00:36, 22.09it/s, loss=0.891, sparse_categorical_accuracy=0.7]
# Epoch 1/1:  20%|██        | 202/1000 [00:09<00:38, 20.72it/s, loss=0.887, sparse_categorical_accuracy=0.702]
# Epoch 1/1:  20%|██        | 205/1000 [00:09<00:37, 21.21it/s, loss=0.884, sparse_categorical_accuracy=0.702]
# Epoch 1/1:  21%|██        | 208/1000 [00:09<00:38, 20.66it/s, loss=0.882, sparse_categorical_accuracy=0.704]
# Epoch 1/1:  21%|██        | 211/1000 [00:10<00:37, 21.27it/s, loss=0.882, sparse_categorical_accuracy=0.704]
# Epoch 1/1:  21%|██▏       | 214/1000 [00:10<00:34, 22.55it/s, loss=0.875, sparse_categorical_accuracy=0.706]
# Epoch 1/1:  22%|██▏       | 217/1000 [00:10<00:35, 21.80it/s, loss=0.871, sparse_categorical_accuracy=0.707]
# Epoch 1/1:  22%|██▏       | 220/1000 [00:10<00:34, 22.74it/s, loss=0.871, sparse_categorical_accuracy=0.708]
# Epoch 1/1:  22%|██▏       | 223/1000 [00:10<00:34, 22.67it/s, loss=0.866, sparse_categorical_accuracy=0.71]
# Epoch 1/1:  23%|██▎       | 226/1000 [00:10<00:34, 22.53it/s, loss=0.861, sparse_categorical_accuracy=0.711]
# Epoch 1/1:  23%|██▎       | 229/1000 [00:10<00:35, 21.92it/s, loss=0.857, sparse_categorical_accuracy=0.712]
# Epoch 1/1:  23%|██▎       | 232/1000 [00:10<00:35, 21.85it/s, loss=0.854, sparse_categorical_accuracy=0.714]
# Epoch 1/1:  24%|██▎       | 235/1000 [00:11<00:37, 20.66it/s, loss=0.848, sparse_categorical_accuracy=0.715]
# Epoch 1/1:  24%|██▍       | 238/1000 [00:11<00:37, 20.59it/s, loss=0.843, sparse_categorical_accuracy=0.717]
# Epoch 1/1:  24%|██▍       | 241/1000 [00:11<00:36, 20.87it/s, loss=0.839, sparse_categorical_accuracy=0.718]
# Epoch 1/1:  24%|██▍       | 244/1000 [00:11<00:35, 21.46it/s, loss=0.838, sparse_categorical_accuracy=0.719]
# Epoch 1/1:  25%|██▍       | 247/1000 [00:11<00:36, 20.43it/s, loss=0.835, sparse_categorical_accuracy=0.72]
# Epoch 1/1:  25%|██▌       | 250/1000 [00:11<00:36, 20.78it/s, loss=0.83, sparse_categorical_accuracy=0.721]
# Epoch 1/1:  25%|██▌       | 253/1000 [00:11<00:36, 20.69it/s, loss=0.825, sparse_categorical_accuracy=0.722]
# Epoch 1/1:  26%|██▌       | 256/1000 [00:12<00:36, 20.51it/s, loss=0.823, sparse_categorical_accuracy=0.723]
# Epoch 1/1:  26%|██▌       | 259/1000 [00:12<00:36, 20.44it/s, loss=0.821, sparse_categorical_accuracy=0.723]
# Epoch 1/1:  26%|██▌       | 262/1000 [00:12<00:35, 21.01it/s, loss=0.817, sparse_categorical_accuracy=0.724]
# Epoch 1/1:  26%|██▋       | 265/1000 [00:12<00:33, 22.14it/s, loss=0.813, sparse_categorical_accuracy=0.725]
# Epoch 1/1:  27%|██▋       | 268/1000 [00:12<00:35, 20.69it/s, loss=0.809, sparse_categorical_accuracy=0.726]
# Epoch 1/1:  27%|██▋       | 271/1000 [00:12<00:35, 20.67it/s, loss=0.805, sparse_categorical_accuracy=0.727]
# Epoch 1/1:  27%|██▋       | 274/1000 [00:12<00:33, 21.64it/s, loss=0.8, sparse_categorical_accuracy=0.729]
# Epoch 1/1:  28%|██▊       | 277/1000 [00:13<00:34, 21.22it/s, loss=0.797, sparse_categorical_accuracy=0.73]
# Epoch 1/1:  28%|██▊       | 280/1000 [00:13<00:34, 21.15it/s, loss=0.796, sparse_categorical_accuracy=0.731]
# Epoch 1/1:  28%|██▊       | 283/1000 [00:13<00:38, 18.75it/s, loss=0.792, sparse_categorical_accuracy=0.732]
# Epoch 1/1:  28%|██▊       | 285/1000 [00:13<00:39, 17.94it/s, loss=0.79, sparse_categorical_accuracy=0.733]
# Epoch 1/1:  29%|██▉       | 288/1000 [00:13<00:37, 18.95it/s, loss=0.789, sparse_categorical_accuracy=0.734]
# Epoch 1/1:  29%|██▉       | 291/1000 [00:13<00:35, 20.04it/s, loss=0.785, sparse_categorical_accuracy=0.735]
# Epoch 1/1:  29%|██▉       | 294/1000 [00:13<00:34, 20.50it/s, loss=0.782, sparse_categorical_accuracy=0.736]
# Epoch 1/1:  30%|██▉       | 297/1000 [00:14<00:35, 19.78it/s, loss=0.779, sparse_categorical_accuracy=0.737]
# Epoch 1/1:  30%|███       | 300/1000 [00:14<00:34, 20.48it/s, loss=0.776, sparse_categorical_accuracy=0.737]
# Epoch 1/1:  30%|███       | 303/1000 [00:14<00:33, 20.69it/s, loss=0.774, sparse_categorical_accuracy=0.738]
# Epoch 1/1:  31%|███       | 306/1000 [00:14<00:34, 19.99it/s, loss=0.771, sparse_categorical_accuracy=0.738]
# Epoch 1/1:  31%|███       | 309/1000 [00:14<00:35, 19.57it/s, loss=0.77, sparse_categorical_accuracy=0.739]
# Epoch 1/1:  31%|███       | 311/1000 [00:14<00:35, 19.58it/s, loss=0.767, sparse_categorical_accuracy=0.74]
# Epoch 1/1:  31%|███▏      | 313/1000 [00:14<00:35, 19.56it/s, loss=0.767, sparse_categorical_accuracy=0.74]
# Epoch 1/1:  32%|███▏      | 316/1000 [00:15<00:35, 19.41it/s, loss=0.764, sparse_categorical_accuracy=0.74]
# Epoch 1/1:  32%|███▏      | 318/1000 [00:15<00:35, 18.99it/s, loss=0.762, sparse_categorical_accuracy=0.741]
# Epoch 1/1:  32%|███▏      | 320/1000 [00:15<00:37, 17.95it/s, loss=0.759, sparse_categorical_accuracy=0.742]
# Epoch 1/1:  32%|███▏      | 323/1000 [00:15<00:35, 19.08it/s, loss=0.757, sparse_categorical_accuracy=0.743]
# Epoch 1/1:  33%|███▎      | 326/1000 [00:15<00:33, 19.90it/s, loss=0.755, sparse_categorical_accuracy=0.744]
# Epoch 1/1:  33%|███▎      | 328/1000 [00:15<00:34, 19.69it/s, loss=0.753, sparse_categorical_accuracy=0.744]
# Epoch 1/1:  33%|███▎      | 331/1000 [00:15<00:32, 20.75it/s, loss=0.752, sparse_categorical_accuracy=0.744]
# Epoch 1/1:  33%|███▎      | 334/1000 [00:15<00:31, 21.28it/s, loss=0.749, sparse_categorical_accuracy=0.745]
# Epoch 1/1:  34%|███▎      | 337/1000 [00:16<00:31, 20.89it/s, loss=0.746, sparse_categorical_accuracy=0.746]
# Epoch 1/1:  34%|███▍      | 340/1000 [00:16<00:30, 21.34it/s, loss=0.743, sparse_categorical_accuracy=0.747]
# Epoch 1/1:  34%|███▍      | 343/1000 [00:16<00:29, 22.45it/s, loss=0.741, sparse_categorical_accuracy=0.748]
# Epoch 1/1:  35%|███▍      | 346/1000 [00:16<00:31, 21.00it/s, loss=0.738, sparse_categorical_accuracy=0.749]
# Epoch 1/1:  35%|███▍      | 349/1000 [00:16<00:31, 20.63it/s, loss=0.736, sparse_categorical_accuracy=0.749]
# Epoch 1/1:  35%|███▌      | 352/1000 [00:16<00:32, 19.85it/s, loss=0.732, sparse_categorical_accuracy=0.751]
# Epoch 1/1:  36%|███▌      | 355/1000 [00:17<00:31, 20.36it/s, loss=0.729, sparse_categorical_accuracy=0.752]
# Epoch 1/1:  36%|███▌      | 358/1000 [00:17<00:30, 21.10it/s, loss=0.728, sparse_categorical_accuracy=0.752]
# Epoch 1/1:  36%|███▌      | 361/1000 [00:17<00:30, 20.68it/s, loss=0.726, sparse_categorical_accuracy=0.753]
# Epoch 1/1:  36%|███▋      | 364/1000 [00:17<00:31, 20.00it/s, loss=0.724, sparse_categorical_accuracy=0.753]
# Epoch 1/1:  37%|███▋      | 367/1000 [00:17<00:30, 20.62it/s, loss=0.723, sparse_categorical_accuracy=0.753]
# Epoch 1/1:  37%|███▋      | 370/1000 [00:17<00:30, 20.99it/s, loss=0.722, sparse_categorical_accuracy=0.754]
# Epoch 1/1:  37%|███▋      | 373/1000 [00:17<00:28, 22.21it/s, loss=0.72, sparse_categorical_accuracy=0.755]
# Epoch 1/1:  38%|███▊      | 376/1000 [00:18<00:29, 20.95it/s, loss=0.719, sparse_categorical_accuracy=0.755]
# Epoch 1/1:  38%|███▊      | 379/1000 [00:18<00:29, 20.73it/s, loss=0.717, sparse_categorical_accuracy=0.755]
# Epoch 1/1:  38%|███▊      | 382/1000 [00:18<00:28, 21.84it/s, loss=0.716, sparse_categorical_accuracy=0.756]
# Epoch 1/1:  38%|███▊      | 385/1000 [00:18<00:29, 20.62it/s, loss=0.713, sparse_categorical_accuracy=0.756]
# Epoch 1/1:  39%|███▉      | 388/1000 [00:18<00:29, 20.56it/s, loss=0.711, sparse_categorical_accuracy=0.757]
# Epoch 1/1:  39%|███▉      | 391/1000 [00:18<00:28, 21.73it/s, loss=0.71, sparse_categorical_accuracy=0.758]
# Epoch 1/1:  39%|███▉      | 394/1000 [00:18<00:29, 20.27it/s, loss=0.709, sparse_categorical_accuracy=0.758]
# Epoch 1/1:  40%|███▉      | 397/1000 [00:19<00:30, 19.76it/s, loss=0.709, sparse_categorical_accuracy=0.758]
# Epoch 1/1:  40%|████      | 400/1000 [00:19<00:30, 19.41it/s, loss=0.706, sparse_categorical_accuracy=0.758]
# Epoch 1/1:  40%|████      | 402/1000 [00:19<00:32, 18.55it/s, loss=0.705, sparse_categorical_accuracy=0.759]
# Epoch 1/1:  40%|████      | 404/1000 [00:19<00:31, 18.79it/s, loss=0.704, sparse_categorical_accuracy=0.759]
# Epoch 1/1:  41%|████      | 407/1000 [00:19<00:30, 19.36it/s, loss=0.703, sparse_categorical_accuracy=0.76]
# Epoch 1/1:  41%|████      | 410/1000 [00:19<00:27, 21.16it/s, loss=0.701, sparse_categorical_accuracy=0.76]
# Epoch 1/1:  41%|████▏     | 413/1000 [00:19<00:27, 21.46it/s, loss=0.699, sparse_categorical_accuracy=0.761]
# Epoch 1/1:  42%|████▏     | 416/1000 [00:19<00:28, 20.26it/s, loss=0.696, sparse_categorical_accuracy=0.762]
# Epoch 1/1:  42%|████▏     | 419/1000 [00:20<00:29, 19.57it/s, loss=0.695, sparse_categorical_accuracy=0.762]
# Epoch 1/1:  42%|████▏     | 421/1000 [00:20<00:29, 19.57it/s, loss=0.694, sparse_categorical_accuracy=0.763]
# Epoch 1/1:  42%|████▏     | 423/1000 [00:20<00:29, 19.60it/s, loss=0.693, sparse_categorical_accuracy=0.763]
# Epoch 1/1:  43%|████▎     | 426/1000 [00:20<00:26, 21.33it/s, loss=0.691, sparse_categorical_accuracy=0.763]
# Epoch 1/1:  43%|████▎     | 429/1000 [00:20<00:27, 21.02it/s, loss=0.69, sparse_categorical_accuracy=0.763]
# Epoch 1/1:  43%|████▎     | 432/1000 [00:20<00:26, 21.34it/s, loss=0.688, sparse_categorical_accuracy=0.764]
# Epoch 1/1:  44%|████▎     | 435/1000 [00:20<00:25, 21.87it/s, loss=0.687, sparse_categorical_accuracy=0.765]
# Epoch 1/1:  44%|████▍     | 438/1000 [00:21<00:26, 21.13it/s, loss=0.686, sparse_categorical_accuracy=0.765]
# Epoch 1/1:  44%|████▍     | 441/1000 [00:21<00:26, 20.80it/s, loss=0.683, sparse_categorical_accuracy=0.766]
# Epoch 1/1:  44%|████▍     | 444/1000 [00:21<00:25, 22.05it/s, loss=0.682, sparse_categorical_accuracy=0.766]
# Epoch 1/1:  45%|████▍     | 447/1000 [00:21<00:25, 21.59it/s, loss=0.682, sparse_categorical_accuracy=0.766]
# Epoch 1/1:  45%|████▌     | 450/1000 [00:21<00:26, 21.06it/s, loss=0.68, sparse_categorical_accuracy=0.767]
# Epoch 1/1:  45%|████▌     | 453/1000 [00:21<00:28, 19.48it/s, loss=0.678, sparse_categorical_accuracy=0.768]
# Epoch 1/1:  46%|████▌     | 456/1000 [00:21<00:26, 20.86it/s, loss=0.677, sparse_categorical_accuracy=0.768]
# Epoch 1/1:  46%|████▌     | 459/1000 [00:22<00:27, 19.87it/s, loss=0.677, sparse_categorical_accuracy=0.768]
# Epoch 1/1:  46%|████▌     | 462/1000 [00:22<00:26, 20.59it/s, loss=0.675, sparse_categorical_accuracy=0.769]
# Epoch 1/1:  46%|████▋     | 465/1000 [00:22<00:26, 19.91it/s, loss=0.674, sparse_categorical_accuracy=0.769]
# Epoch 1/1:  47%|████▋     | 468/1000 [00:22<00:26, 20.01it/s, loss=0.672, sparse_categorical_accuracy=0.769]
# Epoch 1/1:  47%|████▋     | 471/1000 [00:22<00:25, 20.44it/s, loss=0.673, sparse_categorical_accuracy=0.769]
# Epoch 1/1:  47%|████▋     | 474/1000 [00:22<00:24, 21.88it/s, loss=0.672, sparse_categorical_accuracy=0.769]
# Epoch 1/1:  48%|████▊     | 477/1000 [00:22<00:23, 22.01it/s, loss=0.671, sparse_categorical_accuracy=0.769]
# Epoch 1/1:  48%|████▊     | 480/1000 [00:23<00:24, 21.48it/s, loss=0.669, sparse_categorical_accuracy=0.769]
# Epoch 1/1:  48%|████▊     | 483/1000 [00:23<00:23, 21.84it/s, loss=0.668, sparse_categorical_accuracy=0.769]
# Epoch 1/1:  49%|████▊     | 486/1000 [00:23<00:22, 22.87it/s, loss=0.668, sparse_categorical_accuracy=0.769]
# Epoch 1/1:  49%|████▉     | 489/1000 [00:23<00:23, 22.00it/s, loss=0.667, sparse_categorical_accuracy=0.77]
# Epoch 1/1:  49%|████▉     | 492/1000 [00:23<00:23, 21.70it/s, loss=0.667, sparse_categorical_accuracy=0.77]
# Epoch 1/1:  50%|████▉     | 495/1000 [00:23<00:22, 22.29it/s, loss=0.666, sparse_categorical_accuracy=0.77]
# Epoch 1/1:  50%|████▉     | 498/1000 [00:23<00:23, 20.93it/s, loss=0.665, sparse_categorical_accuracy=0.771]
# Epoch 1/1:  50%|█████     | 501/1000 [00:24<00:23, 21.10it/s, loss=0.666, sparse_categorical_accuracy=0.77]
# Epoch 1/1:  50%|█████     | 504/1000 [00:24<00:23, 20.97it/s, loss=0.665, sparse_categorical_accuracy=0.771]
# Epoch 1/1:  51%|█████     | 507/1000 [00:24<00:22, 22.17it/s, loss=0.664, sparse_categorical_accuracy=0.771]
# Epoch 1/1:  51%|█████     | 510/1000 [00:24<00:23, 20.86it/s, loss=0.663, sparse_categorical_accuracy=0.772]
# Epoch 1/1:  51%|█████▏    | 513/1000 [00:24<00:24, 19.92it/s, loss=0.661, sparse_categorical_accuracy=0.772]
# Epoch 1/1:  52%|█████▏    | 516/1000 [00:24<00:23, 20.51it/s, loss=0.661, sparse_categorical_accuracy=0.772]
# Epoch 1/1:  52%|█████▏    | 519/1000 [00:24<00:22, 20.98it/s, loss=0.66, sparse_categorical_accuracy=0.773]
# Epoch 1/1:  52%|█████▏    | 522/1000 [00:25<00:23, 20.22it/s, loss=0.659, sparse_categorical_accuracy=0.773]
# Epoch 1/1:  52%|█████▎    | 525/1000 [00:25<00:22, 21.08it/s, loss=0.658, sparse_categorical_accuracy=0.773]
# Epoch 1/1:  53%|█████▎    | 528/1000 [00:25<00:20, 22.71it/s, loss=0.657, sparse_categorical_accuracy=0.774]
# Epoch 1/1:  53%|█████▎    | 531/1000 [00:25<00:21, 21.91it/s, loss=0.657, sparse_categorical_accuracy=0.773]
# Epoch 1/1:  53%|█████▎    | 534/1000 [00:25<00:21, 22.07it/s, loss=0.656, sparse_categorical_accuracy=0.774]
# Epoch 1/1:  54%|█████▎    | 537/1000 [00:25<00:20, 22.15it/s, loss=0.656, sparse_categorical_accuracy=0.774]
# Epoch 1/1:  54%|█████▍    | 540/1000 [00:25<00:21, 21.50it/s, loss=0.656, sparse_categorical_accuracy=0.774]
# Epoch 1/1:  54%|█████▍    | 543/1000 [00:26<00:21, 21.11it/s, loss=0.654, sparse_categorical_accuracy=0.774]
# Epoch 1/1:  55%|█████▍    | 546/1000 [00:26<00:21, 21.45it/s, loss=0.652, sparse_categorical_accuracy=0.775]
# Epoch 1/1:  55%|█████▍    | 549/1000 [00:26<00:22, 20.38it/s, loss=0.651, sparse_categorical_accuracy=0.775]
# Epoch 1/1:  55%|█████▌    | 552/1000 [00:26<00:23, 19.42it/s, loss=0.651, sparse_categorical_accuracy=0.775]
# Epoch 1/1:  56%|█████▌    | 555/1000 [00:26<00:21, 21.06it/s, loss=0.65, sparse_categorical_accuracy=0.775]
# Epoch 1/1:  56%|█████▌    | 558/1000 [00:26<00:21, 20.81it/s, loss=0.649, sparse_categorical_accuracy=0.776]
# Epoch 1/1:  56%|█████▌    | 561/1000 [00:26<00:20, 21.29it/s, loss=0.648, sparse_categorical_accuracy=0.776]
# Epoch 1/1:  56%|█████▋    | 564/1000 [00:27<00:21, 20.18it/s, loss=0.647, sparse_categorical_accuracy=0.776]
# Epoch 1/1:  57%|█████▋    | 567/1000 [00:27<00:21, 19.85it/s, loss=0.647, sparse_categorical_accuracy=0.777]
# Epoch 1/1:  57%|█████▋    | 570/1000 [00:27<00:21, 20.18it/s, loss=0.645, sparse_categorical_accuracy=0.777]
# Epoch 1/1:  57%|█████▋    | 573/1000 [00:27<00:21, 19.46it/s, loss=0.644, sparse_categorical_accuracy=0.778]
# Epoch 1/1:  58%|█████▊    | 576/1000 [00:27<00:20, 20.31it/s, loss=0.644, sparse_categorical_accuracy=0.778]
# Epoch 1/1:  58%|█████▊    | 579/1000 [00:27<00:19, 21.65it/s, loss=0.644, sparse_categorical_accuracy=0.778]
# Epoch 1/1:  58%|█████▊    | 582/1000 [00:27<00:20, 20.50it/s, loss=0.642, sparse_categorical_accuracy=0.778]
# Epoch 1/1:  58%|█████▊    | 585/1000 [00:28<00:19, 20.99it/s, loss=0.641, sparse_categorical_accuracy=0.779]
# Epoch 1/1:  59%|█████▉    | 588/1000 [00:28<00:18, 21.71it/s, loss=0.642, sparse_categorical_accuracy=0.779]
# Epoch 1/1:  59%|█████▉    | 591/1000 [00:28<00:18, 21.70it/s, loss=0.641, sparse_categorical_accuracy=0.779]
# Epoch 1/1:  59%|█████▉    | 594/1000 [00:28<00:19, 21.20it/s, loss=0.64, sparse_categorical_accuracy=0.779]
# Epoch 1/1:  60%|█████▉    | 597/1000 [00:28<00:19, 20.86it/s, loss=0.641, sparse_categorical_accuracy=0.779]
# Epoch 1/1:  60%|██████    | 600/1000 [00:28<00:18, 21.30it/s, loss=0.641, sparse_categorical_accuracy=0.779]
# Epoch 1/1:  60%|██████    | 603/1000 [00:28<00:18, 21.63it/s, loss=0.641, sparse_categorical_accuracy=0.779]
# Epoch 1/1:  61%|██████    | 606/1000 [00:29<00:17, 21.93it/s, loss=0.639, sparse_categorical_accuracy=0.78]
# Epoch 1/1:  61%|██████    | 609/1000 [00:29<00:17, 22.91it/s, loss=0.638, sparse_categorical_accuracy=0.78]
# Epoch 1/1:  61%|██████    | 612/1000 [00:29<00:19, 19.84it/s, loss=0.638, sparse_categorical_accuracy=0.78]
# Epoch 1/1:  62%|██████▏   | 615/1000 [00:29<00:19, 19.91it/s, loss=0.637, sparse_categorical_accuracy=0.78]
# Epoch 1/1:  62%|██████▏   | 618/1000 [00:29<00:18, 20.53it/s, loss=0.635, sparse_categorical_accuracy=0.781]
# Epoch 1/1:  62%|██████▏   | 621/1000 [00:29<00:17, 21.08it/s, loss=0.634, sparse_categorical_accuracy=0.781]
# Epoch 1/1:  62%|██████▏   | 624/1000 [00:29<00:18, 20.82it/s, loss=0.633, sparse_categorical_accuracy=0.782]
# Epoch 1/1:  63%|██████▎   | 627/1000 [00:30<00:18, 20.58it/s, loss=0.632, sparse_categorical_accuracy=0.782]
# Epoch 1/1:  63%|██████▎   | 630/1000 [00:30<00:18, 19.67it/s, loss=0.631, sparse_categorical_accuracy=0.782]
# Epoch 1/1:  63%|██████▎   | 632/1000 [00:30<00:19, 18.96it/s, loss=0.631, sparse_categorical_accuracy=0.782]
# Epoch 1/1:  63%|██████▎   | 634/1000 [00:30<00:19, 18.64it/s, loss=0.631, sparse_categorical_accuracy=0.782]
# Epoch 1/1:  64%|██████▎   | 637/1000 [00:30<00:18, 19.81it/s, loss=0.63, sparse_categorical_accuracy=0.783]
# Epoch 1/1:  64%|██████▍   | 640/1000 [00:30<00:17, 20.64it/s, loss=0.629, sparse_categorical_accuracy=0.783]
# Epoch 1/1:  64%|██████▍   | 643/1000 [00:30<00:18, 19.78it/s, loss=0.628, sparse_categorical_accuracy=0.784]
# Epoch 1/1:  64%|██████▍   | 645/1000 [00:30<00:17, 19.76it/s, loss=0.627, sparse_categorical_accuracy=0.784]
# Epoch 1/1:  65%|██████▍   | 648/1000 [00:31<00:17, 20.61it/s, loss=0.627, sparse_categorical_accuracy=0.784]
# Epoch 1/1:  65%|██████▌   | 651/1000 [00:31<00:17, 19.72it/s, loss=0.627, sparse_categorical_accuracy=0.784]
# Epoch 1/1:  65%|██████▌   | 653/1000 [00:31<00:18, 18.29it/s, loss=0.626, sparse_categorical_accuracy=0.785]
# Epoch 1/1:  66%|██████▌   | 655/1000 [00:31<00:18, 18.62it/s, loss=0.625, sparse_categorical_accuracy=0.785]
# Epoch 1/1:  66%|██████▌   | 658/1000 [00:31<00:17, 19.82it/s, loss=0.625, sparse_categorical_accuracy=0.785]
# Epoch 1/1:  66%|██████▌   | 661/1000 [00:31<00:16, 20.74it/s, loss=0.623, sparse_categorical_accuracy=0.786]
# Epoch 1/1:  66%|██████▋   | 664/1000 [00:31<00:15, 22.15it/s, loss=0.623, sparse_categorical_accuracy=0.786]
# Epoch 1/1:  67%|██████▋   | 667/1000 [00:32<00:15, 21.32it/s, loss=0.623, sparse_categorical_accuracy=0.785]
# Epoch 1/1:  67%|██████▋   | 670/1000 [00:32<00:15, 21.55it/s, loss=0.623, sparse_categorical_accuracy=0.786]
# Epoch 1/1:  67%|██████▋   | 673/1000 [00:32<00:14, 22.85it/s, loss=0.621, sparse_categorical_accuracy=0.786]
# Epoch 1/1:  68%|██████▊   | 676/1000 [00:32<00:14, 22.73it/s, loss=0.621, sparse_categorical_accuracy=0.786]
# Epoch 1/1:  68%|██████▊   | 679/1000 [00:32<00:13, 22.93it/s, loss=0.62, sparse_categorical_accuracy=0.786]
# Epoch 1/1:  68%|██████▊   | 682/1000 [00:32<00:14, 21.76it/s, loss=0.621, sparse_categorical_accuracy=0.786]
# Epoch 1/1:  68%|██████▊   | 685/1000 [00:32<00:14, 22.10it/s, loss=0.62, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  69%|██████▉   | 688/1000 [00:32<00:14, 22.25it/s, loss=0.62, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  69%|██████▉   | 691/1000 [00:33<00:14, 20.87it/s, loss=0.62, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  69%|██████▉   | 694/1000 [00:33<00:15, 19.86it/s, loss=0.62, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  70%|██████▉   | 697/1000 [00:33<00:14, 20.44it/s, loss=0.62, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  70%|███████   | 700/1000 [00:33<00:15, 19.81it/s, loss=0.619, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  70%|███████   | 703/1000 [00:33<00:15, 19.27it/s, loss=0.619, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  71%|███████   | 706/1000 [00:33<00:14, 20.75it/s, loss=0.619, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  71%|███████   | 709/1000 [00:34<00:14, 19.90it/s, loss=0.618, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  71%|███████   | 712/1000 [00:34<00:14, 20.48it/s, loss=0.617, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  72%|███████▏  | 715/1000 [00:34<00:13, 21.17it/s, loss=0.617, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  72%|███████▏  | 718/1000 [00:34<00:13, 21.44it/s, loss=0.617, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  72%|███████▏  | 721/1000 [00:34<00:14, 19.74it/s, loss=0.616, sparse_categorical_accuracy=0.787]
# Epoch 1/1:  72%|███████▏  | 724/1000 [00:34<00:13, 20.46it/s, loss=0.616, sparse_categorical_accuracy=0.788]
# Epoch 1/1:  73%|███████▎  | 727/1000 [00:34<00:13, 20.88it/s, loss=0.615, sparse_categorical_accuracy=0.788]
# Epoch 1/1:  73%|███████▎  | 730/1000 [00:35<00:12, 21.42it/s, loss=0.614, sparse_categorical_accuracy=0.788]
# Epoch 1/1:  73%|███████▎  | 733/1000 [00:35<00:13, 20.22it/s, loss=0.614, sparse_categorical_accuracy=0.788]
# Epoch 1/1:  74%|███████▎  | 736/1000 [00:35<00:12, 20.42it/s, loss=0.614, sparse_categorical_accuracy=0.788]
# Epoch 1/1:  74%|███████▍  | 739/1000 [00:35<00:12, 20.28it/s, loss=0.614, sparse_categorical_accuracy=0.788]
# Epoch 1/1:  74%|███████▍  | 742/1000 [00:35<00:12, 20.72it/s, loss=0.614, sparse_categorical_accuracy=0.788]
# Epoch 1/1:  74%|███████▍  | 745/1000 [00:35<00:11, 21.40it/s, loss=0.613, sparse_categorical_accuracy=0.789]
# Epoch 1/1:  75%|███████▍  | 748/1000 [00:35<00:11, 21.64it/s, loss=0.612, sparse_categorical_accuracy=0.788]
# Epoch 1/1:  75%|███████▌  | 751/1000 [00:36<00:11, 21.92it/s, loss=0.612, sparse_categorical_accuracy=0.789]
# Epoch 1/1:  75%|███████▌  | 754/1000 [00:36<00:11, 22.11it/s, loss=0.61, sparse_categorical_accuracy=0.789]
# Epoch 1/1:  76%|███████▌  | 757/1000 [00:36<00:10, 22.40it/s, loss=0.61, sparse_categorical_accuracy=0.789]
# Epoch 1/1:  76%|███████▌  | 760/1000 [00:36<00:11, 21.54it/s, loss=0.609, sparse_categorical_accuracy=0.789]
# Epoch 1/1:  76%|███████▋  | 763/1000 [00:36<00:11, 20.34it/s, loss=0.608, sparse_categorical_accuracy=0.789]
# Epoch 1/1:  77%|███████▋  | 766/1000 [00:36<00:11, 20.92it/s, loss=0.608, sparse_categorical_accuracy=0.79]
# Epoch 1/1:  77%|███████▋  | 769/1000 [00:36<00:10, 21.40it/s, loss=0.607, sparse_categorical_accuracy=0.79]
# Epoch 1/1:  77%|███████▋  | 772/1000 [00:37<00:11, 20.17it/s, loss=0.606, sparse_categorical_accuracy=0.79]
# Epoch 1/1:  78%|███████▊  | 775/1000 [00:37<00:11, 20.32it/s, loss=0.606, sparse_categorical_accuracy=0.79]
# Epoch 1/1:  78%|███████▊  | 778/1000 [00:37<00:10, 21.49it/s, loss=0.606, sparse_categorical_accuracy=0.79]
# Epoch 1/1:  78%|███████▊  | 781/1000 [00:37<00:09, 21.92it/s, loss=0.606, sparse_categorical_accuracy=0.79]
# Epoch 1/1:  78%|███████▊  | 784/1000 [00:37<00:09, 22.04it/s, loss=0.605, sparse_categorical_accuracy=0.79]
# Epoch 1/1:  79%|███████▊  | 787/1000 [00:37<00:09, 21.44it/s, loss=0.605, sparse_categorical_accuracy=0.79]
# Epoch 1/1:  79%|███████▉  | 790/1000 [00:37<00:10, 20.95it/s, loss=0.604, sparse_categorical_accuracy=0.791]
# Epoch 1/1:  79%|███████▉  | 793/1000 [00:38<00:09, 21.30it/s, loss=0.604, sparse_categorical_accuracy=0.79]
# Epoch 1/1:  80%|███████▉  | 796/1000 [00:38<00:09, 21.74it/s, loss=0.603, sparse_categorical_accuracy=0.791]
# Epoch 1/1:  80%|███████▉  | 799/1000 [00:38<00:08, 22.78it/s, loss=0.603, sparse_categorical_accuracy=0.791]
# Epoch 1/1:  80%|████████  | 802/1000 [00:38<00:08, 23.62it/s, loss=0.604, sparse_categorical_accuracy=0.791]
# Epoch 1/1:  80%|████████  | 805/1000 [00:38<00:08, 21.73it/s, loss=0.603, sparse_categorical_accuracy=0.791]
# Epoch 1/1:  81%|████████  | 808/1000 [00:38<00:09, 20.46it/s, loss=0.603, sparse_categorical_accuracy=0.791]
# Epoch 1/1:  81%|████████  | 811/1000 [00:38<00:09, 20.95it/s, loss=0.603, sparse_categorical_accuracy=0.791]
# Epoch 1/1:  81%|████████▏ | 814/1000 [00:38<00:08, 20.71it/s, loss=0.602, sparse_categorical_accuracy=0.791]
# Epoch 1/1:  82%|████████▏ | 817/1000 [00:39<00:08, 21.82it/s, loss=0.602, sparse_categorical_accuracy=0.791]
# Epoch 1/1:  82%|████████▏ | 820/1000 [00:39<00:08, 22.14it/s, loss=0.602, sparse_categorical_accuracy=0.791]
# Epoch 1/1:  82%|████████▏ | 823/1000 [00:39<00:07, 22.31it/s, loss=0.602, sparse_categorical_accuracy=0.792]
# Epoch 1/1:  83%|████████▎ | 826/1000 [00:39<00:07, 22.33it/s, loss=0.601, sparse_categorical_accuracy=0.792]
# Epoch 1/1:  83%|████████▎ | 829/1000 [00:39<00:07, 22.36it/s, loss=0.6, sparse_categorical_accuracy=0.792]
# Epoch 1/1:  83%|████████▎ | 832/1000 [00:39<00:07, 23.45it/s, loss=0.6, sparse_categorical_accuracy=0.792]
# Epoch 1/1:  84%|████████▎ | 835/1000 [00:39<00:07, 23.09it/s, loss=0.599, sparse_categorical_accuracy=0.792]
# Epoch 1/1:  84%|████████▍ | 838/1000 [00:40<00:07, 22.90it/s, loss=0.599, sparse_categorical_accuracy=0.793]
# Epoch 1/1:  84%|████████▍ | 841/1000 [00:40<00:07, 20.97it/s, loss=0.598, sparse_categorical_accuracy=0.793]
# Epoch 1/1:  84%|████████▍ | 844/1000 [00:40<00:07, 19.57it/s, loss=0.598, sparse_categorical_accuracy=0.793]
# Epoch 1/1:  85%|████████▍ | 847/1000 [00:40<00:07, 19.66it/s, loss=0.598, sparse_categorical_accuracy=0.793]
# Epoch 1/1:  85%|████████▍ | 849/1000 [00:40<00:07, 19.58it/s, loss=0.598, sparse_categorical_accuracy=0.793]
# Epoch 1/1:  85%|████████▌ | 852/1000 [00:40<00:07, 19.91it/s, loss=0.598, sparse_categorical_accuracy=0.793]
# Epoch 1/1:  86%|████████▌ | 855/1000 [00:40<00:07, 20.62it/s, loss=0.597, sparse_categorical_accuracy=0.793]
# Epoch 1/1:  86%|████████▌ | 858/1000 [00:41<00:06, 20.41it/s, loss=0.597, sparse_categorical_accuracy=0.793]
# Epoch 1/1:  86%|████████▌ | 861/1000 [00:41<00:06, 20.59it/s, loss=0.597, sparse_categorical_accuracy=0.793]
# Epoch 1/1:  86%|████████▋ | 864/1000 [00:41<00:06, 20.93it/s, loss=0.596, sparse_categorical_accuracy=0.793]
# Epoch 1/1:  87%|████████▋ | 867/1000 [00:41<00:06, 20.04it/s, loss=0.595, sparse_categorical_accuracy=0.794]
# Epoch 1/1:  87%|████████▋ | 870/1000 [00:41<00:06, 20.56it/s, loss=0.595, sparse_categorical_accuracy=0.794]
# Epoch 1/1:  87%|████████▋ | 873/1000 [00:41<00:06, 19.17it/s, loss=0.594, sparse_categorical_accuracy=0.794]
# Epoch 1/1:  88%|████████▊ | 875/1000 [00:41<00:06, 19.20it/s, loss=0.594, sparse_categorical_accuracy=0.794]
# Epoch 1/1:  88%|████████▊ | 878/1000 [00:42<00:06, 20.25it/s, loss=0.594, sparse_categorical_accuracy=0.794]
# Epoch 1/1:  88%|████████▊ | 881/1000 [00:42<00:05, 21.15it/s, loss=0.593, sparse_categorical_accuracy=0.795]
# Epoch 1/1:  88%|████████▊ | 884/1000 [00:42<00:05, 21.31it/s, loss=0.593, sparse_categorical_accuracy=0.795]
# Epoch 1/1:  89%|████████▊ | 887/1000 [00:42<00:05, 21.68it/s, loss=0.593, sparse_categorical_accuracy=0.795]
# Epoch 1/1:  89%|████████▉ | 890/1000 [00:42<00:05, 21.83it/s, loss=0.592, sparse_categorical_accuracy=0.795]
# Epoch 1/1:  89%|████████▉ | 893/1000 [00:42<00:05, 20.80it/s, loss=0.591, sparse_categorical_accuracy=0.795]
# Epoch 1/1:  90%|████████▉ | 896/1000 [00:42<00:04, 21.81it/s, loss=0.591, sparse_categorical_accuracy=0.795]
# Epoch 1/1:  90%|████████▉ | 899/1000 [00:43<00:04, 21.34it/s, loss=0.591, sparse_categorical_accuracy=0.795]
# Epoch 1/1:  90%|█████████ | 902/1000 [00:43<00:04, 20.99it/s, loss=0.59, sparse_categorical_accuracy=0.796]
# Epoch 1/1:  90%|█████████ | 905/1000 [00:43<00:04, 19.52it/s, loss=0.59, sparse_categorical_accuracy=0.796]
# Epoch 1/1:  91%|█████████ | 908/1000 [00:43<00:04, 20.78it/s, loss=0.589, sparse_categorical_accuracy=0.796]
# Epoch 1/1:  91%|█████████ | 911/1000 [00:43<00:04, 20.58it/s, loss=0.589, sparse_categorical_accuracy=0.796]
# Epoch 1/1:  91%|█████████▏| 914/1000 [00:43<00:04, 21.10it/s, loss=0.588, sparse_categorical_accuracy=0.796]
# Epoch 1/1:  92%|█████████▏| 917/1000 [00:43<00:03, 20.82it/s, loss=0.587, sparse_categorical_accuracy=0.797]
# Epoch 1/1:  92%|█████████▏| 920/1000 [00:44<00:03, 20.51it/s, loss=0.587, sparse_categorical_accuracy=0.797]
# Epoch 1/1:  92%|█████████▏| 923/1000 [00:44<00:03, 20.79it/s, loss=0.587, sparse_categorical_accuracy=0.797]
# Epoch 1/1:  93%|█████████▎| 926/1000 [00:44<00:03, 21.52it/s, loss=0.586, sparse_categorical_accuracy=0.797]
# Epoch 1/1:  93%|█████████▎| 929/1000 [00:44<00:03, 21.82it/s, loss=0.585, sparse_categorical_accuracy=0.797]
# Epoch 1/1:  93%|█████████▎| 932/1000 [00:44<00:03, 21.30it/s, loss=0.584, sparse_categorical_accuracy=0.798]
# Epoch 1/1:  94%|█████████▎| 935/1000 [00:44<00:03, 20.89it/s, loss=0.584, sparse_categorical_accuracy=0.798]
# Epoch 1/1:  94%|█████████▍| 938/1000 [00:44<00:03, 19.97it/s, loss=0.584, sparse_categorical_accuracy=0.798]
# Epoch 1/1:  94%|█████████▍| 941/1000 [00:45<00:02, 20.59it/s, loss=0.583, sparse_categorical_accuracy=0.798]
# Epoch 1/1:  94%|█████████▍| 944/1000 [00:45<00:02, 20.50it/s, loss=0.583, sparse_categorical_accuracy=0.798]
# Epoch 1/1:  95%|█████████▍| 947/1000 [00:45<00:02, 21.01it/s, loss=0.582, sparse_categorical_accuracy=0.798]
# Epoch 1/1:  95%|█████████▌| 950/1000 [00:45<00:02, 20.83it/s, loss=0.582, sparse_categorical_accuracy=0.798]
# Epoch 1/1:  95%|█████████▌| 953/1000 [00:45<00:02, 20.53it/s, loss=0.582, sparse_categorical_accuracy=0.798]
# Epoch 1/1:  96%|█████████▌| 956/1000 [00:45<00:02, 21.02it/s, loss=0.581, sparse_categorical_accuracy=0.799]
# Epoch 1/1:  96%|█████████▌| 959/1000 [00:45<00:01, 21.50it/s, loss=0.58, sparse_categorical_accuracy=0.799]
# Epoch 1/1:  96%|█████████▌| 962/1000 [00:46<00:01, 21.03it/s, loss=0.58, sparse_categorical_accuracy=0.799]
# Epoch 1/1:  96%|█████████▋| 965/1000 [00:46<00:01, 19.96it/s, loss=0.579, sparse_categorical_accuracy=0.799]
# Epoch 1/1:  97%|█████████▋| 968/1000 [00:46<00:01, 19.52it/s, loss=0.579, sparse_categorical_accuracy=0.799]
# Epoch 1/1:  97%|█████████▋| 971/1000 [00:46<00:01, 20.22it/s, loss=0.578, sparse_categorical_accuracy=0.799]
# Epoch 1/1:  97%|█████████▋| 974/1000 [00:46<00:01, 20.17it/s, loss=0.579, sparse_categorical_accuracy=0.799]
# Epoch 1/1:  98%|█████████▊| 977/1000 [00:46<00:01, 18.94it/s, loss=0.578, sparse_categorical_accuracy=0.799]
# Epoch 1/1:  98%|█████████▊| 979/1000 [00:46<00:01, 18.33it/s, loss=0.578, sparse_categorical_accuracy=0.8]
# Epoch 1/1:  98%|█████████▊| 981/1000 [00:47<00:01, 17.50it/s, loss=0.577, sparse_categorical_accuracy=0.8]
# Epoch 1/1:  98%|█████████▊| 983/1000 [00:47<00:00, 17.51it/s, loss=0.577, sparse_categorical_accuracy=0.8]
# Epoch 1/1:  98%|█████████▊| 985/1000 [00:47<00:00, 17.87it/s, loss=0.577, sparse_categorical_accuracy=0.8]
# Epoch 1/1:  99%|█████████▊| 987/1000 [00:47<00:00, 16.97it/s, loss=0.577, sparse_categorical_accuracy=0.8]
# Epoch 1/1:  99%|█████████▉| 989/1000 [00:47<00:00, 16.36it/s, loss=0.576, sparse_categorical_accuracy=0.8]
# Epoch 1/1:  99%|█████████▉| 991/1000 [00:47<00:00, 15.40it/s, loss=0.576, sparse_categorical_accuracy=0.8]
# Epoch 1/1:  99%|█████████▉| 993/1000 [00:47<00:00, 15.86it/s, loss=0.576, sparse_categorical_accuracy=0.8]
# Epoch 1/1: 100%|█████████▉| 995/1000 [00:47<00:00, 16.23it/s, loss=0.576, sparse_categorical_accuracy=0.8]
# Epoch 1/1: 100%|█████████▉| 997/1000 [00:48<00:00, 15.90it/s, loss=0.575, sparse_categorical_accuracy=0.8]
# Epoch 1/1: 100%|██████████| 1000/1000 [00:48<00:00, 20.71it/s, loss=0.575, sparse_categorical_accuracy=0.801]
# All epochs: 100%|██████████| 1/1 [00:50<00:00, 50.23s/it]
